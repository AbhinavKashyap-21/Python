# %%
if __name__ == '__main__':
    
    n = int(input())
    integer_list = map(int, input().split())
    t = ()
    t = integer_list
    result = hash(t)
    print(result)
# Out:
#  2
#  1 2
# -3550055125485641917

# %%
if __name__ == '__main__':
    
    n = int(input())
    integer_list = map(int, input().split())
    t = tuple(integer_list)
    print(t)
# Out:
#  2
#  12
# 860454829093830431

# %%
a = "this is a string"
a = a.split(" ")
print(a)

a = "-".join(a)
# Out:
# ['this', 'is', 'a', 'string']
# 'this-is-a-string'

# %%
def mutate_string(string, position, character):
    global s 
    s = s[:int(i)] + character + s[int(i):]  
    return s

if __name__ == '__main__':
    s = input()
    i, c = input().split()
    s_new = mutate_string(s, int(i), c)
    print(s_new)
# Out:
#  abracadabra
#  5 k
# abrackadabra
